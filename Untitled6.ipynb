# %% [markdown]
# <a href="https://colab.research.google.com/github/OffsetParadise/Data-Science-Portfolio/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Libraries

import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
#Load the Dataset

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"

df = pd.read_csv(url)

df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Check Data Types

df.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
#Handle Missing Values

df["age"] = df["age"].fillna(df["age"].median())
df["embarked"] = df["embarked"].fillna(df["embarked"].mode()[0])

# %%
#Label Encoding

le = LabelEncoder()

df["sex"] = le.fit_transform(df["sex"])

df["embarked"] = le.fit_transform(df["embarked"])

# %%
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500         2  Third    man
# 1         1       1    0  38.0      1      0  71.2833         0  First  woman
# 2         1       3    0  26.0      0      0   7.9250         2  Third  woman
# 3         1       1    0  35.0      1      0  53.1000         2  First  woman
# 4         0       3    1  35.0      0      0   8.0500         2  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
#Create a New Feature

df["FamilySize"] = df["sibsp"] + df["parch"] + 1

# %%
df[["sibsp", "parch", "FamilySize"]].head()
# Out:
#    sibsp  parch  FamilySize
# 0      1      0           2
# 1      1      0           2
# 2      0      0           1
# 3      1      0           2
# 4      0      0           1

# %%
#Create an "IsAlone" Feature

df["IsAlone"] = np.where(df["FamilySize"] == 1, 1, 0)

# %%
df[["FamilySize", "IsAlone"]].head()
# Out:
#    FamilySize  IsAlone
# 0           2        0
# 1           2        0
# 2           1        1
# 3           2        0
# 4           1        1

# %%
scaler = StandardScaler()

df["Age_scaled"] = scaler.fit_transform(df[["age"]])

# %%
df[["age", "Age_scaled"]].head()
# Out:
#     age  Age_scaled
# 0  22.0   -0.565736
# 1  38.0    0.663861
# 2  26.0   -0.258337
# 3  35.0    0.433312
# 4  35.0    0.433312

# %%
#Save the Processed Dataset

df.to_csv("feature_engineered_titanic.csv", index=False)

# %%
from google.colab import files

files.download("feature_engineered_titanic.csv")
